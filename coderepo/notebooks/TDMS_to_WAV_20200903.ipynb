# %%
import sys
import os

import numpy as np
import pandas as pd
# import matplotlib.pyplot as plt
# plt.style.use('seaborn-colorblind')
import datetime
from nptdms import TdmsFile
import wave

sys.path.append('../')
import CaptureTracker as ct

### some convenient magics
# %load_ext autoreload
# %autoreload 2

# %%
datadir = '../../data/'
datafiles = sorted([x for x in os.listdir(datadir) if 'FastWaveforms' in x])

# %%
filename = os.path.join(datadir, datafiles[0])

# %%
dat = TdmsFile(filename)

# %%
dat.as_dataframe()
# Out:
#        /'FastWaveforms'/'Tower_base_bending_1'  \
# 0                                     0.000184
# 1                                     0.000183
# 2                                     0.000181
# 3                                     0.000185
# 4                                     0.000184
# ...                                        ...
# 60035                                 0.000207
# 60036                                 0.000206
# 60037                                 0.000207
# 60038                                 0.000205
# 60039                                 0.000204
#
#        /'FastWaveforms'/'Tower_base_bending_2'  \
# 0                                    -0.000316
# 1                                    -0.000318
# 2                                    -0.000318
# 3                                    -0.000310
# 4                                    -0.000312
# ...                                        ...
# 60035                                -0.000296
# 60036                                -0.000295
# 60037                                -0.000297
# 60038                                -0.000299
# 60039                                -0.000293
#
#        /'FastWaveforms'/'Tower_base_torque'  /'FastWaveforms'/'base_spare_2'  \
# 0                                  0.000042                        -0.024975
# 1                                  0.000044                        -0.024975
# 2                                  0.000042                        -0.024975
# 3                                  0.000044                        -0.024975
# 4                                  0.000042                        -0.024975
# ...                                     ...                              ...
# 60035                              0.000047                        -0.024975
# 60036                              0.000045                        -0.024975
# 60037                              0.000045                        -0.024975
# 60038                              0.000045                        -0.024975
# 60039                              0.000046                        -0.024975
#
#        /'FastWaveforms'/'Tower_top_bending_1'  \
# 0                                   -0.000069
# 1                                   -0.000071
# 2                                   -0.000071
# 3                                   -0.000072
# 4                                   -0.000070
# ...                                       ...
# 60035                               -0.000042
# 60036                               -0.000040
# 60037                               -0.000040
# 60038                               -0.000038
# 60039                               -0.000037
#
#        /'FastWaveforms'/'Tower_top_bending_2'  \
# 0                                    0.000006
# 1                                    0.000004
# 2                                    0.000004
# 3                                    0.000005
# 4                                    0.000004
# ...                                       ...
# 60035                                0.000010
# 60036                                0.000009
# 60037                                0.000010
# 60038                                0.000009
# 60039                                0.000007
#
#        /'FastWaveforms'/'Tower_top_torque'  /'FastWaveforms'/'top_spare_1'  \
# 0                                 0.000019                       -0.022153
# 1                                 0.000016                       -0.022179
# 2                                 0.000018                       -0.022106
# 3                                 0.000020                       -0.022095
# 4                                 0.000018                       -0.022143
# ...                                    ...                             ...
# 60035                             0.000035                       -0.021527
# 60036                             0.000032                       -0.021580
# 60037                             0.000031                       -0.021643
# 60038                             0.000030                       -0.021474
# 60039                             0.000032                       -0.021403
#
#        /'FastWaveforms'/'Tower_top_accel_x'  \
# 0                                 -0.006465
# 1                                 -0.004555
# 2                                  0.013026
# 3                                  0.003555
# 4                                 -0.001641
# ...                                     ...
# 60035                              0.012892
# 60036                              0.031393
# 60037                              0.001743
# 60038                              0.008859
# 60039                              0.010174
#
#        /'FastWaveforms'/'Tower_top_accel_y'  ...  /'FastWaveforms'/'Vwind'  \
# 0                                 -0.057168  ...                 12.518875
# 1                                 -0.027263  ...                 12.518875
# 2                                 -0.006550  ...                 12.518875
# 3                                 -0.021229  ...                 12.518875
# 4                                 -0.050464  ...                 12.518875
# ...                                     ...  ...                       ...
# 60035                             -0.031868  ...                 11.677654
# 60036                             -0.030458  ...                 11.677654
# 60037                             -0.032144  ...                 11.677654
# 60038                             -0.037562  ...                 11.677654
# 60039                             -0.064911  ...                 11.677654
#
#        /'FastWaveforms'/'Year'  /'FastWaveforms'/'Precipitation'  \
# 0                    70.729088                          0.005874
# 1                    70.729088                          0.005874
# 2                    70.729088                          0.005874
# 3                    70.729088                          0.005874
# 4                    70.729088                          0.005874
# ...                        ...                               ...
# 60035                70.732536                          0.005999
# 60036                70.732536                          0.005999
# 60037                70.732536                          0.005999
# 60038                70.732536                          0.005999
# 60039                70.732536                          0.005999
#
#        /'FastWaveforms'/'Pressure_85m'  /'FastWaveforms'/'Temperature_85m'  \
# 0                            80.071037                           10.609339
# 1                            80.071037                           10.609339
# 2                            80.071037                           10.609339
# 3                            80.071037                           10.609339
# 4                            80.071037                           10.609339
# ...                                ...                                 ...
# 60035                        80.055374                           10.928514
# 60036                        80.055374                           10.928514
# 60037                        80.055374                           10.928514
# 60038                        80.055374                           10.928514
# 60039                        80.055374                           10.928514
#
#        /'FastWaveforms'/'WindDirection_87m'  /'FastWaveforms'/'WindSpeed_80m'  \
# 0                                267.257385                          14.29653
# 1                                267.257385                          14.29653
# 2                                267.257385                          14.29653
# 3                                267.257385                          14.29653
# 4                                267.257385                          14.29653
# ...                                     ...                               ...
# 60035                            265.137695                          15.48707
# 60036                            265.137695                          15.48707
# 60037                            265.137695                          15.48707
# 60038                            265.137695                          15.48707
# 60039                            265.137695                          15.48707
#
#        /'FastWaveforms'/'WindSpeed_87m'  /'FastWaveforms'/'WindSpeed_90m_1'  \
# 0                             14.871221                            15.25960
# 1                             14.871221                            15.25960
# 2                             14.871221                            15.25960
# 3                             14.871221                            15.25960
# 4                             14.871221                            15.25960
# ...                                 ...                                 ...
# 60035                         15.901456                            15.31072
# 60036                         15.901456                            15.31072
# 60037                         15.901456                            15.31072
# 60038                         15.901456                            15.31072
# 60039                         15.901456                            15.31072
#
#        /'FastWaveforms'/'WindSpeed_90m_2'
# 0                                 15.2596
# 1                                 15.2596
# 2                                 15.2596
# 3                                 15.2596
# 4                                 15.2596
# ...                                   ...
# 60035                             15.2596
# 60036                             15.2596
# 60037                             15.2596
# 60038                             15.2596
# 60039                             15.2596
#
# [60040 rows x 53 columns]

# %%
wave.__str__()
# Out:
# "<module 'wave' from '/usr/local/Cellar/python/3.7.6_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/wave.py'>"
